# %% [markdown]
# <a href="https://colab.research.google.com/github/NPCA-TEAM/COVID-19/blob/main/INTEGRAR_DADOS_covid_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instalação e importação de bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.7/dist-packages (3.0.3)

# %%
import os
import glob
import pandas as pd # dataframes
import numpy as nd
import matplotlib.pyplot as plt # plotagem dos dados
import os
import time
from datetime import datetime, timedelta, date

# %% [markdown]
# # **CASOS**

# %% [markdown]
# #Leitura e visualização dos dados

# %% [markdown]
# ##Casos média móvel Atual, 7 Dias, 14 Dias

# %%
#Seleciona os arquivos de CASOS recentemente baixado da pasta de .CSVs (LakeData)
pasta = '/content/drive/MyDrive/NPCA - COVID/LakeData/Casos/' 
lista_de_arquivos_casos = glob.glob(pasta+'*') 
print(*lista_de_arquivos_casos, sep = '\n')
print('-----------------------------------------------------------------------------')
# Out:
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_11_2022.csv
# -----------------------------------------------------------------------------

# %%
#Indice dos arquivos na lista ordenada. ALTERAR NUMEROS PARA 7 E 14 QUANDO TIVERMOS AO MENOS 15 ARQUIVOS NA PASTA
indice_Setimo_dia_casos = 7
indice_DecimoQuarto_dia_casos = 14

#Ordena arquivos por data de criação do arquivo. Ultimo arquivo a ser criado começa no inicio da lista.
lista_de_arquivos_ordenados_casos= sorted(lista_de_arquivos_casos,key=os.path.getctime,reverse=True)
print(*lista_de_arquivos_ordenados_casos,sep = "\n")
print('---------------------------------------------------------------------------')
# Out:
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_18_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_13_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_10_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_31_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_20_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_19_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_17_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_15_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_14_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_12_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_08_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_06_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_04_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_03_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_02_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_28_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_27_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_26_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_25_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_24_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_22_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_21_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_30_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_09_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_07_01_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_23_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_01_12_2021.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_16_12_2021.csv
# ---------------------------------------------------------------------------

# %%
#Seleciona o ultimo arquivo que foi criado e adicioado na pasta
arquivo_atual_casos = lista_de_arquivos_ordenados_casos[0]
#Seleciona o setimo arquivo que foi criado depois do ultimo arquivo adicionado na pasta
arquivo_7dias_casos = lista_de_arquivos_ordenados_casos[indice_Setimo_dia_casos]
#Seleciona o decimo quarto arquivo que foi criado depois do ultimo arquivo adicionado na pasta
arquivo_14dias_casos = lista_de_arquivos_ordenados_casos[indice_DecimoQuarto_dia_casos]

print('--------------------------------------------------------------------------------')
print(arquivo_atual_casos)
print(arquivo_7dias_casos)
print(arquivo_14dias_casos)
# Out:
# --------------------------------------------------------------------------------
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_11_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Casos/MMC_PA_29_10_2022.csv

# %%
#Importando arquivos
casos_media_movel_atual = pd.read_csv(arquivo_atual_casos, parse_dates=['data'])
casos_media_movel_atual.info()

casos_media_movel_7dias = pd.read_csv(arquivo_7dias_casos, parse_dates=['data'])
casos_media_movel_7dias.info()

casos_media_movel_14dias = pd.read_csv(arquivo_14dias_casos, parse_dates=['data'])
casos_media_movel_14dias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          986 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do sintoma     986 non-null    float64
#  2   Qtd. pela data da publicação  986 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 23.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          980 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do sintoma     980 non-null    float64
#  2   Qtd. pela data da publicação  980 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 23.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          973 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do sintoma     973 non-null    float64
#  2   Qtd. pela data da publicação  973 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 22.9 KB

# %% [markdown]
# #Porcentagem de vacinação: primeira, segunda e terceira dose.

# %%
# importando os dados da COVID diretamente do GitHub
dados = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")

# alterar a coluna de data para o formato de data e hora
dados['date'] = pd.to_datetime(dados['date'])

# Filtrando os dados do Braisl, e mostrando apenas as colunas especificas:
dados_PA_vacinados = dados.query("state == 'PA'")[['date', 
                                                   'vaccinated_per_100_inhabitants',
                                                   'vaccinated_second_per_100_inhabitants',
                                                   'vaccinated_third_per_100_inhabitants']]

dados_PA_vacinados.columns=['data','Vacinacao_Dose1_PA','Vacinacao_Dose2_PA','Vacinacao_Dose3_PA']

# imprimindo todas as colunas disponiveis
#print(dados.columns)

# Imprimindo os dados:
#dados_PA_vacinados.plot.line(title='Vaccination doses in Pará', x="data", y= ['Vacinacao_dose1_PA',
#                                                                              'Vacinacao_dose2_PA',
#                                                                             'Vacinacao_dose3_PA'], figsize=(16,4)).grid();

plt.figure(figsize=(16, 4))
plt.grid()
plt.xlabel('date')
plt.ylabel('doses')
plt.title('COVID-19 Vaccination graph in Pará')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose1_PA'], label='Vaccination_dose1_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose2_PA'], label='Vaccination_dose2_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose3_PA'], label='Vaccination_dose3_PA')
plt.legend()

# Salvando o gráfico em PNG:
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Vaccination doses in Pará - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')

# Imprimindo o dataframe:
print(dados_PA_vacinados)
# Out:
#             data  Vacinacao_Dose1_PA  Vacinacao_Dose2_PA  Vacinacao_Dose3_PA
# 176   2020-03-18                 NaN                 NaN                 NaN
# 198   2020-03-19                 NaN                 NaN                 NaN
# 224   2020-03-20                 NaN                 NaN                 NaN
# 251   2020-03-21                 NaN                 NaN                 NaN
# 279   2020-03-22                 NaN                 NaN                 NaN
# ...          ...                 ...                 ...                 ...
# 27187 2022-11-08             79.8519            75.45159            28.97859
# 27215 2022-11-09             79.8519            75.45159            28.97859
# 27243 2022-11-10             79.8519            75.45159            28.97859
# 27271 2022-11-11             79.8519            75.45159            28.97859
# 27299 2022-11-12             79.8519            75.45159            28.97859
#
# [970 rows x 4 columns]

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# ##Tratamento para casos média móvel

# %%
#     PARA O DIA ATUAL - CASOS

# Filtrando apenas a data e retirando o horario:
casos_media_movel_atual['data'] = pd.to_datetime(casos_media_movel_atual['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
casos_media_movel_atual = casos_media_movel_atual.set_index('data')

#Alterando nome das colunas
casos_media_movel_atual = casos_media_movel_atual.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_MM_atual_PA','Qtd. pela data do sintoma':'Casos_DataSintoma_MM_atual_PA'})                                                            
                                
# Plotando os dados:
strDiaColetado = str(casos_media_movel_atual.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_atual.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}', figsize=(16,3)).grid()


################## MEXENDO AQUI ########################
# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('doses')
#plt.title(f'Moving average of COVID-19 cases in Pará - Data collected day {strDiaColetado}')
plt.title(f'Moving average of COVID-19 cases in Pará')
plt.plot(casos_media_movel_atual['Casos_DataSintoma_MM_atual_PA'], label='Cases_DateSymptom_MM_Current_PA')
plt.plot(casos_media_movel_atual['Casos_Publicacao_MM_atual_PA'], label='Cases_Publication_MM_Current_PA')
plt.legend()

print(casos_media_movel_atual) 

# Salvando o frafico em PNG:
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average of cases in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')     
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average of cases in Pará - Data collected day  {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Casos_DataSintoma_MM_atual_PA  Casos_Publicacao_MM_atual_PA
# data
# 2020-03-01                      20.571429                      0.000000
# 2020-03-02                      26.285714                      0.000000
# 2020-03-03                      35.714286                      0.000000
# 2020-03-04                      40.142857                      0.000000
# 2020-03-05                      68.000000                      0.000000
# ...                                   ...                           ...
# 2022-11-07                      33.857143                    134.285714
# 2022-11-08                      30.857143                    169.428571
# 2022-11-09                      28.857143                    212.571429
# 2022-11-10                      25.714286                    210.714286
# 2022-11-11                      18.714286                    221.142857
#
# [986 rows x 2 columns]

# %%
#      PARA 7 DIAS - CASOS

# Filtrando apenas a data e retirando o horario
casos_media_movel_7dias['data'] = pd.to_datetime(casos_media_movel_7dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
casos_media_movel_7dias = casos_media_movel_7dias.set_index('data')

#Alterando nome das colunas
casos_media_movel_7dias = casos_media_movel_7dias.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_MM_7dias_PA','Qtd. pela data do sintoma':'Casos_DataSintoma_MM_7dias_PA'})

                                                                                                    #Tradução para Ingles:
                                                                                                    #Cases_Publication_Moving_Average_7_days_PA
                                                                                                    #Cases_of_Moving_Average_Symptom_7_days_PA
                                                                                                                                                                                             

# Plotando os dados:
strDiaColetado = str(casos_media_movel_7dias.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_7dias.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}\n', figsize=(16,3)).grid()

                                                                                                    #Tradução para Ingles:
                                                                                                    #Moving average of COVID-19 cases in Pará - Data collected daily
# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('cases')
#plt.title(f'Moving average for 7 days of COVID-19 cases in Pará - Data collected day {strDiaColetado}')
plt.title(f'Moving average for 7 days of COVID-19 cases in Pará')
plt.plot(casos_media_movel_7dias['Casos_DataSintoma_MM_7dias_PA'], label='Cases_DateSymptom_MM_7days_PA')
plt.plot(casos_media_movel_7dias['Casos_Publicacao_MM_7dias_PA'], label='Cases_Publication_MM_7days_PA')
plt.legend()

print(casos_media_movel_7dias)  

# Salvando o frafico em PNG:
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 7 days of COVID-19 cases in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 7 days of COVID-19 cases in Pará - Data collected day  {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Casos_DataSintoma_MM_7dias_PA  Casos_Publicacao_MM_7dias_PA
# data
# 2020-03-01                      20.571429                      0.000000
# 2020-03-02                      26.285714                      0.000000
# 2020-03-03                      35.714286                      0.000000
# 2020-03-04                      40.142857                      0.000000
# 2020-03-05                      68.000000                      0.000000
# ...                                   ...                           ...
# 2022-11-01                      14.428571                    126.571429
# 2022-11-02                      11.285714                     92.428571
# 2022-11-03                       9.285714                     98.428571
# 2022-11-04                       8.857143                    109.285714
# 2022-11-05                       7.714286                    118.571429
#
# [980 rows x 2 columns]

# %%
#         PARA 14 DIAS - CASOS

# Filtrando apenas a data e retirando o horario:
casos_media_movel_14dias['data'] = pd.to_datetime(casos_media_movel_14dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
casos_media_movel_14dias = casos_media_movel_14dias.set_index('data')

#Alterando nome das colunas
casos_media_movel_14dias = casos_media_movel_14dias.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_MM_14dias_PA','Qtd. pela data do sintoma':'Casos_DataSintoma_MM_14dias_PA'})
                                                                                 

#Plotando os dados:
strDiaColetado = str(casos_media_movel_14dias.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_14dias.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado,} \n', figsize=(16,3)).grid()

                                                                                                    #Tradução para Ingles:
                                                                                                    #Moving average of COVID-19 cases in Pará - Data collected daily
# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('cases')
#plt.title(f'Moving average for 14 days of COVID-19 cases in Pará - Data collected day {strDiaColetado}')
plt.title(f'Moving average for 14 days of COVID-19 cases in Pará')
plt.plot(casos_media_movel_14dias['Casos_DataSintoma_MM_14dias_PA'], label='Cases_DateSymptom_MM_14days_PA')
plt.plot(casos_media_movel_14dias['Casos_Publicacao_MM_14dias_PA'], label='Cases_Publication_MM_14days_PA')
plt.legend()

print(casos_media_movel_14dias)         

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 14 days of COVID-19 cases in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 14 days of COVID-19 cases in Pará - Data collected day  {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Casos_DataSintoma_MM_14dias_PA  Casos_Publicacao_MM_14dias_PA
# data
# 2020-03-01                       20.571429                       0.000000
# 2020-03-02                       26.285714                       0.000000
# 2020-03-03                       35.714286                       0.000000
# 2020-03-04                       40.142857                       0.000000
# 2020-03-05                       68.000000                       0.000000
# ...                                    ...                            ...
# 2022-10-25                       20.000000                     181.714286
# 2022-10-26                       16.571429                     177.142857
# 2022-10-27                       13.857143                     162.285714
# 2022-10-28                       11.142857                     167.000000
# 2022-10-29                        8.857143                     160.571429
#
# [973 rows x 2 columns]

# %% [markdown]
# ## Ocultar

# %%
#-------PARA O DIA ATUAL CASOS--------

# Filtrando apenas a data e retirando o horario
#casos_media_movel_atual['data'] = pd.to_datetime(casos_media_movel_atual['data'].dt.strftime('%Y-%m-%d'))
# Tornando Data em indice:
#casos_media_movel_atual = casos_media_movel_atual.set_index('data')
#Alterando nome das colunas
    #casos_media_movel_atual = casos_media_movel_atual.rename(columns={'data':'date','Qtd. pela data da publicação':'Cases_Publication_Current_Moving_Average_PA','Qtd. pela data do sintoma':'Cases_Date_Symptom_Current_Moving_Average_PA'})
#casos_media_movel_atual = casos_media_movel_atual.rename(columns={"Qtd. pela data da publicação":"Casos_Publicacao_MM_atual_PA","Qtd. pela data do sintoma":"Casos_DataSintoma_MM_atual_PA"})

                                                                                                    #Tradução para Ingles:
                                                                                                    #Cases_Publication_Current_Moving_Average_PA
                                                                                                    #Cases_Date_Symptom_Current_Moving_Average_PA

# Plotando os dados:
#strDiaColetado = str(casos_media_movel_atual.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_atual.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}', figsize=(16,3)).grid()
    #casos_media_movel_atual.plot.line(title=f'Média móveis de casos de COVID-19 no Pará - Dados coletados dia {strDiaColetado}', figsize=(16,3)).grid()

                                                                                                    #Tradução para Ingles:
                                                                                                    #Moving average of COVID-19 cases in Pará - Data collected daily

# SALVANDO AS IMAGEM DO GRAFICO
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/teste/Média móveis de casos de COVID-19 no Pará - Dados coletados dia {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')                                                                                                  #Moving average of COVID-19 cases in Pará - Data collected daily

#####################################################################################################################################################################################################################################################################

#      PARA 7 DIAS

# Filtrando apenas a data e retirando o horario
#casos_media_movel_7dias['data'] = pd.to_datetime(casos_media_movel_7dias['data'].dt.strftime('%Y-%m-%d'))
# Tornando Data em indice:
#casos_media_movel_7dias = casos_media_movel_7dias.set_index('data')
#Alterando nome das colunas
    #casos_media_movel_7dias = casos_media_movel_7dias.rename(columns={'Qtd. pela data da publicação':'Cases_Publication_Moving_Average_7_days_PA','Qtd. pela data do sintoma':'Cases_of_Moving_Average_Symptom_7days_PA'})
#casos_media_movel_7dias = casos_media_movel_7dias.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_MM_7dias_PA','Qtd. pela data do sintoma':'Casos_DataSintoma_MM_7dias_PA'})

                                                                                                    #Tradução para Ingles:
                                                                                                    #Cases_Publication_Moving_Average_7_days_PA
                                                                                                    #Cases_of_Moving_Average_Symptom_7_days_PA
                                                                                                    
# Plotando os dados:
#strDiaColetado = str(casos_media_movel_7dias.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_7dias.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}\n', figsize=(16,3)).grid()
#casos_media_movel_7dias.plot.line(title=f'Média móveis de casos de COVID-19 no Pará - Dados coletados dia {strDiaColetado}\n', figsize=(16,3)).grid()

                                                                                                    #Tradução para Ingles:
                                                                                                    #Moving average of COVID-19 cases in Pará - Data collected daily

#SALVANDO AS IMAGEM DO GRAFICO
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/teste/Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')

######################################################################################################################################################################################################################################################################

#         PARA 14 DIAS

# Filtrando apenas a data e retirando o horario:
#casos_media_movel_14dias['data'] = pd.to_datetime(casos_media_movel_14dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
#casos_media_movel_14dias = casos_media_movel_14dias.set_index('data')

#Alterando nome das colunas
#casos_media_movel_14dias = casos_media_movel_14dias.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_Media_Movel_14_days_PA','Qtd. pela data do sintoma':'Cases_of_Moving_Average_Symptom_14_days_PA'})
#casos_media_movel_14dias = casos_media_movel_14dias.rename(columns={'Qtd. pela data da publicação':'Casos_Publicacao_MM_14dias_PA','Qtd. pela data do sintoma':'Casos_DataSintoma_MM_14dias_PA'})

                                                                                                    #Tradução para Ingles:
                                                                                                    #Cases_Publication_Moving_Average_14_days_PA
                                                                                                    #Cases_of_Moving_Average_Symptom_14_days_PA

#Plotando os dados:
#strDiaColetado = str(casos_media_movel_14dias.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#casos_media_movel_14dias.plot.line(title=f'Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}\n', figsize=(16,3)).grid()
#casos_media_movel_14dias.plot.line(title=f'Média móveis de casos de COVID-19 no Pará - Dados coletados dia {strDiaColetado}\n', figsize=(16,3)).grid()

                                                                                                    #Tradução para Ingles:
                                                                                                    #Moving average of COVID-19 cases in Pará - Data collected daily

# SALVANDO AS IMAGEM DO GRAFICO
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/teste/Moving average of COVID-19 cases in Pará - Data collected daily {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ##Tratamento de vacinação

# %%
# Normalização e criação de novas colunas em decimais (0=0% e 1=100%)
dados_PA_vacinados['Vacinacao_Dose1_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose1_PA'] * 0.01                                                               
dados_PA_vacinados['Vacinacao_Dose2_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose2_PA'] * 0.01
dados_PA_vacinados['Vacinacao_Dose3_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose3_PA'] * 0.01

# Filtrando os dados em decimais
dados_PA_vacinacao_dec = dados_PA_vacinados.filter(items = ['data',
                                                            'Vacinacao_Dose1_%decimal_PA',
                                                            'Vacinacao_Dose2_%decimal_PA',
                                                            'Vacinacao_Dose3_%decimal_PA'])

#print(dados_PA_vacinacao_dec.columns)
#dados_PA_vacinacao_dec.plot.line(title='COVID-19 vaccination graph in Pará', x="data", y=['Vacinacao_Dose1_%decimal_PA',
#                                                                                          'Vacinacao_Dose2_%decimal_PA',
#                                                                                          'Vacinacao_Dose3_%decimal_PA'], figsize=(16,4)).grid();

#Renomeano o nome  das colunas apenas para o gráfico  
plt.figure(figsize=(16, 4))
plt.grid()
plt.xlabel('date')
plt.ylabel('doses')
plt.title('COVID-19 vaccination graph in Pará (Treaty 0-1)')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose1_%decimal_PA'], label='Vaccination_dose1_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose2_%decimal_PA'], label='Vaccination_dose2_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose3_%decimal_PA'], label='Vaccination_dose3_PA')
plt.legend()

print(dados_PA_vacinacao_dec)   

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/COVID-19 Vaccination graph in Pará (Treaty 0-1) - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             data  Vacinacao_Dose1_%decimal_PA  Vacinacao_Dose2_%decimal_PA  \
# 176   2020-03-18                          NaN                          NaN
# 198   2020-03-19                          NaN                          NaN
# 224   2020-03-20                          NaN                          NaN
# 251   2020-03-21                          NaN                          NaN
# 279   2020-03-22                          NaN                          NaN
# ...          ...                          ...                          ...
# 27187 2022-11-08                     0.798519                     0.754516
# 27215 2022-11-09                     0.798519                     0.754516
# 27243 2022-11-10                     0.798519                     0.754516
# 27271 2022-11-11                     0.798519                     0.754516
# 27299 2022-11-12                     0.798519                     0.754516
#
#        Vacinacao_Dose3_%decimal_PA
# 176                            NaN
# 198                            NaN
# 224                            NaN
# 251                            NaN
# 279                            NaN
# ...                            ...
# 27187                     0.289786
# 27215                     0.289786
# 27243                     0.289786
# 27271                     0.289786
# 27299                     0.289786
#
# [970 rows x 4 columns]

# %%
# Tornando Data em indice:
dados_PA_vacinacao_dec = dados_PA_vacinacao_dec.set_index('data')
dados_PA_vacinacao_dec
dados_PA_vacinacao_dec
# Out:
#             Vacinacao_Dose1_%decimal_PA  Vacinacao_Dose2_%decimal_PA  \
# data
# 2020-03-18                          NaN                          NaN
# 2020-03-19                          NaN                          NaN
# 2020-03-20                          NaN                          NaN
# 2020-03-21                          NaN                          NaN
# 2020-03-22                          NaN                          NaN
# ...                                 ...                          ...
# 2022-11-08                     0.798519                     0.754516
# 2022-11-09                     0.798519                     0.754516
# 2022-11-10                     0.798519                     0.754516
# 2022-11-11                     0.798519                     0.754516
# 2022-11-12                     0.798519                     0.754516
#
#             Vacinacao_Dose3_%decimal_PA
# data
# 2020-03-18                          NaN
# 2020-03-19                          NaN
# 2020-03-20                          NaN
# 2020-03-21                          NaN
# 2020-03-22                          NaN
# ...                                 ...
# 2022-11-08                     0.289786
# 2022-11-09                     0.289786
# 2022-11-10                     0.289786
# 2022-11-11                     0.289786
# 2022-11-12                     0.289786
#
# [970 rows x 3 columns]

# %% [markdown]
# #Integração dos dados

# %%
#Integrando dados e imprimindo os dados
dados_unidos = pd.concat([casos_media_movel_atual,  casos_media_movel_7dias, casos_media_movel_14dias, dados_PA_vacinacao_dec], axis=1)

# obitos_media_movel_atual, obitos_media_movel_7dias, obitos_media_movel_14dias,
dados_unidos
# Out:
#             Casos_DataSintoma_MM_atual_PA  Casos_Publicacao_MM_atual_PA  \
# data
# 2020-03-01                      20.571429                      0.000000
# 2020-03-02                      26.285714                      0.000000
# 2020-03-03                      35.714286                      0.000000
# 2020-03-04                      40.142857                      0.000000
# 2020-03-05                      68.000000                      0.000000
# ...                                   ...                           ...
# 2022-11-08                      30.857143                    169.428571
# 2022-11-09                      28.857143                    212.571429
# 2022-11-10                      25.714286                    210.714286
# 2022-11-11                      18.714286                    221.142857
# 2022-11-12                            NaN                           NaN
#
#             Casos_DataSintoma_MM_7dias_PA  Casos_Publicacao_MM_7dias_PA  \
# data
# 2020-03-01                      20.571429                           0.0
# 2020-03-02                      26.285714                           0.0
# 2020-03-03                      35.714286                           0.0
# 2020-03-04                      40.142857                           0.0
# 2020-03-05                      68.000000                           0.0
# ...                                   ...                           ...
# 2022-11-08                            NaN                           NaN
# 2022-11-09                            NaN                           NaN
# 2022-11-10                            NaN                           NaN
# 2022-11-11                            NaN                           NaN
# 2022-11-12                            NaN                           NaN
#
#             Casos_DataSintoma_MM_14dias_PA  Casos_Publicacao_MM_14dias_PA  \
# data
# 2020-03-01                       20.571429                            0.0
# 2020-03-02                       26.285714                            0.0
# 2020-03-03                       35.714286                            0.0
# 2020-03-04                       40.142857                            0.0
# 2020-03-05                       68.000000                            0.0
# ...                                    ...                            ...
# 2022-11-08                             NaN                            NaN
# 2022-11-09                             NaN                            NaN
# 2022-11-10                             NaN                            NaN
# 2022-11-11                             NaN                            NaN
# 2022-11-12                             NaN                            NaN
#
#             Vacinacao_Dose1_%decimal_PA  Vacinacao_Dose2_%decimal_PA  \
# data
# 2020-03-01                          NaN                          NaN
# 2020-03-02                          NaN                          NaN
# 2020-03-03                          NaN                          NaN
# 2020-03-04                          NaN                          NaN
# 2020-03-05                          NaN                          NaN
# ...                                 ...                          ...
# 2022-11-08                     0.798519                     0.754516
# 2022-11-09                     0.798519                     0.754516
# 2022-11-10                     0.798519                     0.754516
# 2022-11-11                     0.798519                     0.754516
# 2022-11-12                     0.798519                     0.754516
#
#             Vacinacao_Dose3_%decimal_PA
# data
# 2020-03-01                          NaN
# 2020-03-02                          NaN
# 2020-03-03                          NaN
# 2020-03-04                          NaN
# 2020-03-05                          NaN
# ...                                 ...
# 2022-11-08                     0.289786
# 2022-11-09                     0.289786
# 2022-11-10                     0.289786
# 2022-11-11                     0.289786
# 2022-11-12                     0.289786
#
# [987 rows x 9 columns]

# %%
# Imprimindo o grafico:
#dados_unidos.plot.line(title='Pará Partial Graph', figsize=(22,8)).grid()

############################################ MEXENDO AQUI ##########################################################
# Plotando os dados:
plt.figure(figsize=(20, 8))
plt.grid()
plt.xlabel('date')
plt.ylabel('data')
plt.title(f'Pará Partial Graph - Data collected daily {strDiaColetado}')

#VACINAÇÃO

plt.plot(dados_unidos['Vacinacao_Dose1_%decimal_PA'], label='Vaccination_dose1_PA')
plt.plot(dados_unidos['Vacinacao_Dose2_%decimal_PA'], label='Vaccination_dose2_PA')
plt.plot(dados_unidos['Vacinacao_Dose3_%decimal_PA'], label='Vaccination_dose3_PA')

#CASOS

#Dias atuais
plt.plot(dados_unidos['Casos_DataSintoma_MM_atual_PA'], label='Cases_DateSymptom_MM_Current_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_atual_PA'], label='Cases_Publication_MM_Current_PA')

#7 dias
plt.plot(dados_unidos['Casos_DataSintoma_MM_7dias_PA'], label='Cases_DateSymptom_MM_7days_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_7dias_PA'], label='Cases_Publication_MM_7days_PA')

#14 dias
plt.plot(dados_unidos['Casos_DataSintoma_MM_14dias_PA'], label='Cases_DateSymptom_MM_14days_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_14dias_PA'], label='Cases_Publication_MM_14days_PA')
plt.legend()

#####################################################################################################################

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Pará Partial Graph - Data collected daily {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# #Exportação dos dados

# %%
# Exportando dados em Excel
pasta_exportacao = "/content/drive/MyDrive/NPCA - COVID/_CASOS/DataSet/"
data_exportacao = time.localtime() 
data_exportacao_string = time.strftime("%d_%m_%Y")
dados_unidos.to_excel(pasta_exportacao+'Dataset_'+str(data_exportacao_string)+'.xlsx', index = True)

# %% [markdown]
# #**OBITOS**

# %% [markdown]
# #Leitura e visualização dos dados

# %% [markdown]
# ##Óbitos média móvel Atual, 7 Dias, 14 Dias

# %%
#Seleciona os arquivos de OBITOS recentemente baixado da pasta de .CSVs (LakeData)
pasta = '/content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/' 
lista_de_arquivos_obitos = glob.glob(pasta+'*') 
print(*lista_de_arquivos_obitos, sep = '\n')
# Out:
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_11_2022.csv

# %%
# Indice dos arquivos na lista ordenada. ALTERAR NUMEROS PARA 7 E 14 QUANDO TIVERMOS AO MENOS 15 ARQUIVOS NA PASTA
indice_Setimo_dia_obitos= 7
indice_DecimoQuarto_dia_obitos = 14

# Ordena arquivos por data de criação do arquivo. Ultimo arquivo a ser criado começa no inicio da lista.
lista_de_arquivos_ordenados_obitos = sorted(lista_de_arquivos_obitos,key=os.path.getctime,reverse=True)
print(*lista_de_arquivos_ordenados_obitos,sep = "\n")
# Out:
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_10_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_09_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_08_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_07_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_06_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_05_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_13_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_10_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_09_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_04_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_31_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_30_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_29_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_22_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_21_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_20_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_19_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_17_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_16_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_15_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_14_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_12_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_08_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_07_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_06_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_04_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_03_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_02_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_01_03_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_28_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_26_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_25_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_24_02_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_23_02_2022.csv

# %%
# Seleciona o ultimo arquivo que foi criado e adicioado na pasta
arquivo_atual_obitos = lista_de_arquivos_ordenados_obitos[0]

# Seleciona o setimo arquivo que foi criado depois do ultimo arquivo adicionado na pasta
arquivo_7dias_obitos = lista_de_arquivos_ordenados_obitos[indice_Setimo_dia_obitos]

# Seleciona o decimo quarto arquivo que foi criado depois do ultimo arquivo adicionado na pasta
arquivo_14dias_obitos = lista_de_arquivos_ordenados_obitos[indice_DecimoQuarto_dia_obitos]

print(arquivo_atual_obitos)
print(arquivo_7dias_obitos)
print(arquivo_14dias_obitos)
# Out:
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_11_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_05_11_2022.csv
# /content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_27_10_2022.csv

# %%
df_teste = pd.read_csv('/content/drive/MyDrive/NPCA - COVID/LakeData/Óbitos/MMO_PA_18_10_2022.csv')
df_teste
# Out:
#                           data  Qtd. pela data do óbito  \
# 0    2020-03-01T00:00:00-03:00                      0.0
# 1    2020-03-02T00:00:00-03:00                      0.0
# 2    2020-03-03T00:00:00-03:00                      0.0
# 3    2020-03-04T00:00:00-03:00                      0.0
# 4    2020-03-05T00:00:00-03:00                      0.0
# ..                         ...                      ...
# 957  2022-10-14T00:00:00-03:00                      0.0
# 958  2022-10-15T00:00:00-03:00                      0.0
# 959  2022-10-16T00:00:00-03:00                      0.0
# 960  2022-10-17T00:00:00-03:00                      0.0
# 961  2022-10-18T00:00:00-03:00                      0.0
#
#      Qtd. pela data da publicação
# 0                        0.000000
# 1                        0.000000
# 2                        0.000000
# 3                        0.000000
# 4                        0.000000
# ..                            ...
# 957                      0.857143
# 958                      0.857143
# 959                      0.857143
# 960                      1.000000
# 961                      1.000000
#
# [962 rows x 3 columns]

# %%
#Importando arquivos
obitos_media_movel_atual = pd.read_csv(arquivo_atual_obitos, parse_dates=['data'])
obitos_media_movel_atual.info()

obitos_media_movel_7dias = pd.read_csv(arquivo_7dias_obitos, parse_dates=['data'])
obitos_media_movel_7dias.info()

obitos_media_movel_14dias = pd.read_csv(arquivo_14dias_obitos, parse_dates=['data'])
obitos_media_movel_14dias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          986 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do óbito       986 non-null    float64
#  2   Qtd. pela data da publicação  986 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 23.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          980 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do óbito       980 non-null    float64
#  2   Qtd. pela data da publicação  980 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 23.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   data                          971 non-null    datetime64[ns, pytz.FixedOffset(-180)]
#  1   Qtd. pela data do óbito       971 non-null    float64
#  2   Qtd. pela data da publicação  971 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-180)](1), float64(2)
# memory usage: 22.9 KB

# %% [markdown]
# ##Porcentagem de vacinação: primeira, segunda e terceira dose.

# %%
# importando os dados da COVID diretamente do GitHub
dados = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")

# alterar a coluna de data para o formato de data e hora
dados['date'] = pd.to_datetime(dados['date'])

# Filtrando os dados do Braisl, e mostrando apenas as colunas especificas
dados_PA_vacinados = dados.query("state == 'PA'")[['date', 
                                                   'vaccinated_per_100_inhabitants',
                                                   'vaccinated_second_per_100_inhabitants',
                                                   'vaccinated_third_per_100_inhabitants']]

dados_PA_vacinados.columns=['data','Vacinacao_Dose1_PA','Vacinacao_Dose2_PA','Vacinacao_Dose3_PA']

# imprimindo todas as colunas disponiveis
#print(dados.columns)

# Plotando os dados
#dados_PA_vacinados.plot.line(title='Vaccination doses in Pará', x="data", y= ['Vacinacao_Dose1_PA',
#                                                                              'Vacinacao_Dose2_PA',
#     
#                                                                         'Vacinacao_Dose3_PA'], figsize=(16,4)).grid(); 
plt.figure(figsize=(16, 4))
plt.grid()
plt.xlabel('date')
plt.ylabel('doses')
plt.title('COVID-19 Vaccination graph in Pará')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose1_PA'], label='Vaccination_Dose1_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose2_PA'], label='Vaccination_Dose2_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose3_PA'], label='Vaccination_Dose3_PA')
plt.legend()

# Imprimindo o dataframe:
print(dados_PA_vacinados)  

# Salvando o gráfico em PNG:
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Vaccination doses in Pará - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             data  Vacinacao_Dose1_PA  Vacinacao_Dose2_PA  Vacinacao_Dose3_PA
# 176   2020-03-18                 NaN                 NaN                 NaN
# 198   2020-03-19                 NaN                 NaN                 NaN
# 224   2020-03-20                 NaN                 NaN                 NaN
# 251   2020-03-21                 NaN                 NaN                 NaN
# 279   2020-03-22                 NaN                 NaN                 NaN
# ...          ...                 ...                 ...                 ...
# 27187 2022-11-08             79.8519            75.45159            28.97859
# 27215 2022-11-09             79.8519            75.45159            28.97859
# 27243 2022-11-10             79.8519            75.45159            28.97859
# 27271 2022-11-11             79.8519            75.45159            28.97859
# 27299 2022-11-12             79.8519            75.45159            28.97859
#
# [970 rows x 4 columns]

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# ##Tratamento para obitos média móvel

# %%
#         PARA O DIA ATUAL - OBITOS

# Filtrando apenas a data e retirando o horario
obitos_media_movel_atual['data'] = pd.to_datetime(obitos_media_movel_atual['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
obitos_media_movel_atual = obitos_media_movel_atual.set_index('data')

#Alterando nome das colunas
obitos_media_movel_atual = obitos_media_movel_atual.rename(columns={"Qtd. pela data do óbito":"Obitos_DataOcorrencia_MM_atual_PA","Qtd. pela data da publicação":"Obitos_Publicacao_MM_atual_PA"}) 
                                                                                               
# Plotando os dados:
strDiaColetado = str(obitos_media_movel_atual.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_atual.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('deaths')
#plt.title(f'Current day moving average of COVID-19 deaths in Pará - Data collected day {strDiaColetado}')
plt.title(f'Current day moving average of COVID-19 deaths in Pará')
plt.plot(obitos_media_movel_atual['Obitos_DataOcorrencia_MM_atual_PA'], label='Deaths_DateOccurrence_MM_Current_PA')
plt.plot(obitos_media_movel_atual['Obitos_Publicacao_MM_atual_PA'], label='Deaths_Publication_MM_Current_PA')
plt.legend()

print(obitos_media_movel_atual) 

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average of deaths from COVID-19 in Pará - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Obitos_DataOcorrencia_MM_atual_PA  Obitos_Publicacao_MM_atual_PA
# data
# 2020-03-01                           0.000000                       0.000000
# 2020-03-02                           0.000000                       0.000000
# 2020-03-03                           0.000000                       0.000000
# 2020-03-04                           0.000000                       0.000000
# 2020-03-05                           0.000000                       0.000000
# ...                                       ...                            ...
# 2022-11-07                           0.142857                       0.571429
# 2022-11-08                           0.142857                       0.571429
# 2022-11-09                           0.142857                       0.857143
# 2022-11-10                           0.142857                       1.142857
# 2022-11-11                           0.285714                       1.142857
#
# [986 rows x 2 columns]

# %%
#         PARA 7 DIAS - OBITOS

# Filtrando apenas a data e retirando o horario
obitos_media_movel_7dias['data'] = pd.to_datetime(obitos_media_movel_7dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
obitos_media_movel_7dias = obitos_media_movel_7dias.set_index('data')


#Alterando nome das colunas
obitos_media_movel_7dias = obitos_media_movel_7dias.rename(columns={"Qtd. pela data do óbito":"Obitos_DataOcorrencia_MM_7dias_PA","Qtd. pela data da publicação":"Obitos_Publicacao_MM_7dias_PA"})

# Plotando os dados:
strDiaColetado = str(obitos_media_movel_7dias.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_7dias.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('deaths')
#plt.title(f'Moving average for 7 days of COVID-19 deaths in Pará - Data collected day {strDiaColetado}')
plt.title(f'Moving average for 7 days of COVID-19 deaths in Pará')
plt.plot(obitos_media_movel_7dias['Obitos_DataOcorrencia_MM_7dias_PA'], label='Deaths_DateOccurrence_MM_7days_PA')
plt.plot(obitos_media_movel_7dias['Obitos_Publicacao_MM_7dias_PA'], label='Deaths_Publication_MM_7days_PA')
plt.legend()

print(obitos_media_movel_7dias)

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 7 days of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 7 days of deaths from COVID-19 in Pará - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Obitos_DataOcorrencia_MM_7dias_PA  Obitos_Publicacao_MM_7dias_PA
# data
# 2020-03-01                                0.0                       0.000000
# 2020-03-02                                0.0                       0.000000
# 2020-03-03                                0.0                       0.000000
# 2020-03-04                                0.0                       0.000000
# 2020-03-05                                0.0                       0.000000
# ...                                       ...                            ...
# 2022-11-01                                0.0                       0.714286
# 2022-11-02                                0.0                       0.571429
# 2022-11-03                                0.0                       0.428571
# 2022-11-04                                0.0                       0.428571
# 2022-11-05                                0.0                       0.428571
#
# [980 rows x 2 columns]

# %%
#         PARA 14 DIAS - OBITOS

# Filtrando apenas a data e retirando o horario
obitos_media_movel_14dias['data'] = pd.to_datetime(obitos_media_movel_14dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
obitos_media_movel_14dias = obitos_media_movel_14dias.set_index('data')

#Alterando nome das colunas
obitos_media_movel_14dias = obitos_media_movel_14dias.rename(columns={"Qtd. pela data do óbito":"Obitos_DataOcorrencia_MM_14dias_PA","Qtd. pela data da publicação":"Obitos_Publicacao_MM_14dias_PA"})

# Plotando os dados:
strDiaColetado = str(obitos_media_movel_14dias.index[-1])
strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_14dias.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

# Plotando os dados:
plt.figure(figsize=(16, 3))
plt.grid()
plt.xlabel('date')
plt.ylabel('deaths')
#plt.title(f'Moving average for 14 days of COVID-19 cases in Pará - Data collected day {strDiaColetado}')
plt.title(f'Moving average for 14 days of COVID-19 cases in Pará')
plt.plot(obitos_media_movel_14dias['Obitos_DataOcorrencia_MM_14dias_PA'], label='Deaths_dateOccurrence_MM_14days_PA')
plt.plot(obitos_media_movel_14dias['Obitos_Publicacao_MM_14dias_PA'], label='Deaths_Publication_MM_14days_PA')
plt.legend()                                                                                                 

print(obitos_media_movel_14dias) 

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 14 days of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}.png', dpi=300, transparent=True, bbox_inches='tight')
#plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Moving average for 14 days of deaths from COVID-19 in Pará - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             Obitos_DataOcorrencia_MM_14dias_PA  Obitos_Publicacao_MM_14dias_PA
# data
# 2020-03-01                                 0.0                        0.000000
# 2020-03-02                                 0.0                        0.000000
# 2020-03-03                                 0.0                        0.000000
# 2020-03-04                                 0.0                        0.000000
# 2020-03-05                                 0.0                        0.000000
# ...                                        ...                             ...
# 2022-10-23                                 0.0                        0.857143
# 2022-10-24                                 0.0                        0.714286
# 2022-10-25                                 0.0                        0.571429
# 2022-10-26                                 0.0                        0.571429
# 2022-10-27                                 0.0                        0.571429
#
# [971 rows x 2 columns]

# %% [markdown]
# ## Ocultar

# %%
#         PARA O DIA ATUAL OBITOS

# Filtrando apenas a data e retirando o horario
#obitos_media_movel_atual['data'] = pd.to_datetime(obitos_media_movel_atual['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
#obitos_media_movel_atual = obitos_media_movel_atual.set_index('data')

#Alterando nome das colunas
#obitos_media_movel_atual = obitos_media_movel_atual.rename(columns={"Qtd. pela data do óbito":"Obitos_DataOcorrencia_MM_atual_PA","Qtd. pela data da publicação":"Obitos_Publicacao_MM_atual_PA"}) 

# Plotando os dados:
#strDiaColetado = str(obitos_media_movel_atual.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_atual.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

####################################################################################################################################################################################################################################################################

#         PARA 7 DIAS

# Filtrando apenas a data e retirando o horario
#obitos_media_movel_7dias['data'] = pd.to_datetime(obitos_media_movel_7dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
#obitos_media_movel_7dias = obitos_media_movel_7dias.set_index('data')

#Alterando nome das colunas
#obitos_media_movel_7dias = obitos_media_movel_7dias.rename(columns={"Qtd. pela data do óbito":"Obitos_DataOcorrencia_MM_7dias_PA","Qtd. pela data da publicação":"Obitos_DataPublicacao_MM_7dias_PA"})

# Plotando os dados:
#strDiaColetado = str(obitos_media_movel_7dias.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_7dias.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

####################################################################################################################################################################################################################################################################

#         PARA 14 DIAS

# Filtrando apenas a data e retirando o horario
#obitos_media_movel_14dias['data'] = pd.to_datetime(obitos_media_movel_14dias['data'].dt.strftime('%Y-%m-%d'))

# Tornando Data em indice:
#obitos_media_movel_14dias = obitos_media_movel_14dias.set_index('data')

#Alterando nome das colunas
#obitos_media_movel_14dias = obitos_media_movel_14dias.rename(columns={"Qtd. pela data do óbito":"Obito_DataOcorrencia_MM_14dias_PA","Qtd. pela data da publicação":"Obitos_DataPublicacao_MM_14dias_PA"})

# Plotando os dados:
#strDiaColetado = str(obitos_media_movel_14dias.index[-1])
#strDiaColetado = strDiaColetado.split(" ")[0]
#obitos_media_movel_14dias.plot.line(title=f'Moving average of deaths from COVID-19 in Pará - Data collected day {strDiaColetado}', figsize=(16,3)).grid()

                                                                                                    #Tradução para inglês
                                                                                                    #Moving average of deaths from COVID-19 in Pará - Data collected day

# %% [markdown]
# ##Tratamento de vacinação

# %%
# Normalização e criação de novas colunas em decimais (0=0% e 1=100%)
dados_PA_vacinados['Vacinacao_Dose1_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose1_PA'] * 0.01                                                                     
dados_PA_vacinados['Vacinacao_Dose2_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose2_PA'] * 0.01
dados_PA_vacinados['Vacinacao_Dose3_%decimal_PA'] = dados_PA_vacinados ['Vacinacao_Dose3_PA'] * 0.01


# Filtrando os dados em decimais
dados_PA_vacinacao_dec = dados_PA_vacinados.filter(items = ['data',
                                                            'Vacinacao_Dose1_%decimal_PA',
                                                            'Vacinacao_Dose2_%decimal_PA',
                                                            'Vacinacao_Dose3_%decimal_PA'])

#dados_PA_vacinacao_dec.plot.line(title='COVID-19 vaccination graph in Pará (Treaty 0-1)', x="data", y=['Vacinacao_Dose1_%decimal_PA',
#                                                                                          'Vacinacao_Dose2_%decimal_PA',
#                                                                                          'Vacinacao_Dose3_%decimal_PA',], figsize=(16,4)).grid();

#Renomeano o nome  das colunas apenas para o gráfico  
plt.figure(figsize=(16, 4))
plt.grid()
plt.xlabel('date')
plt.ylabel('doses')
plt.title('COVID-19 vaccination graph in Pará (Treaty 0-1)')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose1_%decimal_PA'], label='Vaccination_dose1_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose2_%decimal_PA'], label='Vaccination_dose2_PA')
plt.plot(dados_PA_vacinados['data'], dados_PA_vacinados['Vacinacao_Dose3_%decimal_PA'], label='Vaccination_dose3_PA')
plt.legend()

# Imprimindo as DataFrame
print(dados_PA_vacinacao_dec)    

# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/COVID-19 Vaccination graph in Pará (Treaty 0-1) - Data collected day {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')
# Out:
#             data  Vacinacao_Dose1_%decimal_PA  Vacinacao_Dose2_%decimal_PA  \
# 176   2020-03-18                          NaN                          NaN
# 198   2020-03-19                          NaN                          NaN
# 224   2020-03-20                          NaN                          NaN
# 251   2020-03-21                          NaN                          NaN
# 279   2020-03-22                          NaN                          NaN
# ...          ...                          ...                          ...
# 27187 2022-11-08                     0.798519                     0.754516
# 27215 2022-11-09                     0.798519                     0.754516
# 27243 2022-11-10                     0.798519                     0.754516
# 27271 2022-11-11                     0.798519                     0.754516
# 27299 2022-11-12                     0.798519                     0.754516
#
#        Vacinacao_Dose3_%decimal_PA
# 176                            NaN
# 198                            NaN
# 224                            NaN
# 251                            NaN
# 279                            NaN
# ...                            ...
# 27187                     0.289786
# 27215                     0.289786
# 27243                     0.289786
# 27271                     0.289786
# 27299                     0.289786
#
# [970 rows x 4 columns]

# %%
# Tornando Data em indice:
dados_PA_vacinacao_dec = dados_PA_vacinacao_dec.set_index('data')
dados_PA_vacinacao_dec
# Out:
#             Vacinacao_Dose1_%decimal_PA  Vacinacao_Dose2_%decimal_PA  \
# data
# 2020-03-18                          NaN                          NaN
# 2020-03-19                          NaN                          NaN
# 2020-03-20                          NaN                          NaN
# 2020-03-21                          NaN                          NaN
# 2020-03-22                          NaN                          NaN
# ...                                 ...                          ...
# 2022-11-08                     0.798519                     0.754516
# 2022-11-09                     0.798519                     0.754516
# 2022-11-10                     0.798519                     0.754516
# 2022-11-11                     0.798519                     0.754516
# 2022-11-12                     0.798519                     0.754516
#
#             Vacinacao_Dose3_%decimal_PA
# data
# 2020-03-18                          NaN
# 2020-03-19                          NaN
# 2020-03-20                          NaN
# 2020-03-21                          NaN
# 2020-03-22                          NaN
# ...                                 ...
# 2022-11-08                     0.289786
# 2022-11-09                     0.289786
# 2022-11-10                     0.289786
# 2022-11-11                     0.289786
# 2022-11-12                     0.289786
#
# [970 rows x 3 columns]

# %% [markdown]
# #Integração dos dados OBITOS, CASOS E VACINAÇÃO

# %%
#Integrando dados e imprimindo os dados
dados_unidos = pd.concat([obitos_media_movel_atual, obitos_media_movel_7dias, obitos_media_movel_14dias,
                          casos_media_movel_atual,  casos_media_movel_7dias, casos_media_movel_14dias,
                          dados_PA_vacinacao_dec], axis=1)

dados_unidos
# Out:
#             Obitos_DataOcorrencia_MM_atual_PA  Obitos_Publicacao_MM_atual_PA  \
# data
# 2020-03-01                           0.000000                       0.000000
# 2020-03-02                           0.000000                       0.000000
# 2020-03-03                           0.000000                       0.000000
# 2020-03-04                           0.000000                       0.000000
# 2020-03-05                           0.000000                       0.000000
# ...                                       ...                            ...
# 2022-11-08                           0.142857                       0.571429
# 2022-11-09                           0.142857                       0.857143
# 2022-11-10                           0.142857                       1.142857
# 2022-11-11                           0.285714                       1.142857
# 2022-11-12                                NaN                            NaN
#
#             Obitos_DataOcorrencia_MM_7dias_PA  Obitos_Publicacao_MM_7dias_PA  \
# data
# 2020-03-01                                0.0                            0.0
# 2020-03-02                                0.0                            0.0
# 2020-03-03                                0.0                            0.0
# 2020-03-04                                0.0                            0.0
# 2020-03-05                                0.0                            0.0
# ...                                       ...                            ...
# 2022-11-08                                NaN                            NaN
# 2022-11-09                                NaN                            NaN
# 2022-11-10                                NaN                            NaN
# 2022-11-11                                NaN                            NaN
# 2022-11-12                                NaN                            NaN
#
#             Obitos_DataOcorrencia_MM_14dias_PA  \
# data
# 2020-03-01                                 0.0
# 2020-03-02                                 0.0
# 2020-03-03                                 0.0
# 2020-03-04                                 0.0
# 2020-03-05                                 0.0
# ...                                        ...
# 2022-11-08                                 NaN
# 2022-11-09                                 NaN
# 2022-11-10                                 NaN
# 2022-11-11                                 NaN
# 2022-11-12                                 NaN
#
#             Obitos_Publicacao_MM_14dias_PA  Casos_DataSintoma_MM_atual_PA  \
# data
# 2020-03-01                             0.0                      20.571429
# 2020-03-02                             0.0                      26.285714
# 2020-03-03                             0.0                      35.714286
# 2020-03-04                             0.0                      40.142857
# 2020-03-05                             0.0                      68.000000
# ...                                    ...                            ...
# 2022-11-08                             NaN                      30.857143
# 2022-11-09                             NaN                      28.857143
# 2022-11-10                             NaN                      25.714286
# 2022-11-11                             NaN                      18.714286
# 2022-11-12                             NaN                            NaN
#
#             Casos_Publicacao_MM_atual_PA  Casos_DataSintoma_MM_7dias_PA  \
# data
# 2020-03-01                      0.000000                      20.571429
# 2020-03-02                      0.000000                      26.285714
# 2020-03-03                      0.000000                      35.714286
# 2020-03-04                      0.000000                      40.142857
# 2020-03-05                      0.000000                      68.000000
# ...                                  ...                            ...
# 2022-11-08                    169.428571                            NaN
# 2022-11-09                    212.571429                            NaN
# 2022-11-10                    210.714286                            NaN
# 2022-11-11                    221.142857                            NaN
# 2022-11-12                           NaN                            NaN
#
#             Casos_Publicacao_MM_7dias_PA  Casos_DataSintoma_MM_14dias_PA  \
# data
# 2020-03-01                           0.0                       20.571429
# 2020-03-02                           0.0                       26.285714
# 2020-03-03                           0.0                       35.714286
# 2020-03-04                           0.0                       40.142857
# 2020-03-05                           0.0                       68.000000
# ...                                  ...                             ...
# 2022-11-08                           NaN                             NaN
# 2022-11-09                           NaN                             NaN
# 2022-11-10                           NaN                             NaN
# 2022-11-11                           NaN                             NaN
# 2022-11-12                           NaN                             NaN
#
#             Casos_Publicacao_MM_14dias_PA  Vacinacao_Dose1_%decimal_PA  \
# data
# 2020-03-01                            0.0                          NaN
# 2020-03-02                            0.0                          NaN
# 2020-03-03                            0.0                          NaN
# 2020-03-04                            0.0                          NaN
# 2020-03-05                            0.0                          NaN
# ...                                   ...                          ...
# 2022-11-08                            NaN                     0.798519
# 2022-11-09                            NaN                     0.798519
# 2022-11-10                            NaN                     0.798519
# 2022-11-11                            NaN                     0.798519
# 2022-11-12                            NaN                     0.798519
#
#             Vacinacao_Dose2_%decimal_PA  Vacinacao_Dose3_%decimal_PA
# data
# 2020-03-01                          NaN                          NaN
# 2020-03-02                          NaN                          NaN
# 2020-03-03                          NaN                          NaN
# 2020-03-04                          NaN                          NaN
# 2020-03-05                          NaN                          NaN
# ...                                 ...                          ...
# 2022-11-08                     0.754516                     0.289786
# 2022-11-09                     0.754516                     0.289786
# 2022-11-10                     0.754516                     0.289786
# 2022-11-11                     0.754516                     0.289786
# 2022-11-12                     0.754516                     0.289786
#
# [987 rows x 15 columns]

# %%
# Imprimindo o grafico:
#dados_unidos.plot.line(title='Graph of data integration of COVID-19 in Pará', figsize=(23,7)).grid()

############################################ MEXENDO AQUI ##########################################################
# Plotando os dados:
plt.figure(figsize=(22, 8))
plt.grid()
plt.xlabel('date')
plt.ylabel('dados')
plt.title(f'Graph of data integration of COVID-19 in Pará - Data collected daily {strDiaColetado}')

#VACINAÇÃO

plt.plot(dados_unidos['Vacinacao_Dose1_%decimal_PA'], label='Vaccination_dose1_PA')
plt.plot(dados_unidos['Vacinacao_Dose2_%decimal_PA'], label='Vaccination_dose2_PA')
plt.plot(dados_unidos['Vacinacao_Dose3_%decimal_PA'], label='Vaccination_dose3_PA')

#CASOS

#Dias atuais
plt.plot(dados_unidos['Casos_DataSintoma_MM_atual_PA'], label='Cases_DateSymptom_MM_Current_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_atual_PA'], label='Cases_Publication_MM_Current_PA')

#7 dias
plt.plot(dados_unidos['Casos_DataSintoma_MM_7dias_PA'], label='Cases_DateSymptom_MM_7days_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_7dias_PA'], label='Cases_Publication_MM_7days_PA')

#14 dias
plt.plot(dados_unidos['Casos_DataSintoma_MM_14dias_PA'], label='Cases_DateSymptom_MM_14days_PA')
plt.plot(dados_unidos['Casos_Publicacao_MM_14dias_PA'], label='Cases_Publication_MM_14days_PA')

#OBITOS

#Dia atual
plt.plot(dados_unidos['Obitos_DataOcorrencia_MM_atual_PA'], label='Deaths_dateOccurrence_MM_Current_PA')
plt.plot(dados_unidos['Obitos_Publicacao_MM_atual_PA'], label='Deaths_Publication_MM_Current_PA')

#7 dias
#plt.plot(dados_unidos['Obitos_DataOcorrencia_MM_7dias_PA'], label='Deaths_dateOccurrence_MM_7days_PA')
plt.plot(dados_unidos['Obitos_Publicacao_MM_7dias_PA'], label='Deaths_Publication_MM_7days_PA')

#14 dias
plt.plot(dados_unidos['Obitos_DataOcorrencia_MM_14dias_PA'], label='Deaths_dateOccurrence_MM_14days_PA')
plt.plot(dados_unidos['Obitos_Publicacao_MM_14dias_PA'], label='Deaths_Publication_MM_14days_PA')
plt.legend()

################################################################################################################## 
                                                                                                   
# Salvando o frafico em PNG: 
plt.savefig(f'/content/drive/MyDrive/NPCA - COVID/Graficos/Graph of data integration of COVID-19 in Pará - Data collected daily {date.today()}.png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# # Exportação dos dados

# %%
# Exportando dados em Excel
pasta_exportacao = "/content/drive/MyDrive/NPCA - COVID/_OBITOS/DataSet/"
data_exportacao = time.localtime() 
data_exportacao_string = time.strftime("%d_%m_%Y")
dados_unidos.to_excel(pasta_exportacao+'Dataset_'+str(data_exportacao_string)+'.xlsx', index = True)

# %% [markdown]
# Continua no script de INVESTIGAR OS DADOS.
#
# Link:  https://colab.research.google.com/drive/1_Yk77j6wZjSCwAgtUkbSHgT-xWrdSmL3#scrollTo=NJC8mlZdv95Z
